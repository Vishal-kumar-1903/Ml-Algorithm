# %% [markdown]
# ##### Cunfusion Matrix #####

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %%
actual= np.array (["dog","not dog","dog","not dog","dog","not dog","dog","not dog"])
predicted= np.array (["dog","dog","not dog","not dog","dog","not dog","dog","not dog"])

# %%
cm = confusion_matrix(actual,predicted)

# %%
print (cm)
# Out:
# [[3 1]
#  [1 3]]

# %%
print (classification_report(actual,predicted))
# Out:
#               precision    recall  f1-score   support
#
#          dog       0.75      0.75      0.75         4
#      not dog       0.75      0.75      0.75         4
#
#     accuracy                           0.75         8
#    macro avg       0.75      0.75      0.75         8
# weighted avg       0.75      0.75      0.75         8

# %%
sns.heatmap(cm,annot=True,
            xticklabels=["dog","not dog"],
            yticklabels=["dog","not dog"])
# Out:
#   File "/tmp/ipython-input-2046314394.py", line 2
#     (xticklabels =["dog","not dog"],
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
